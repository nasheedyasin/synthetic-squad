# %%
# !pip install openai

# %%
import openai as ai
import pandas as pd
import joblib
# import pickle
# import os

# %%
# ai.api_key = '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' 
#Updated with my API Key
# ai.api_key = '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'
# ai.api_key = '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'
# ai.api_key = "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"

ai.api_key = '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'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompts=[]
# f = open("/content/drive/MyDrive/NLP Group Project/Texts/gpt2_generate.csv","r")
# c = 0
# for i in f:
#     temp = i.split(",")
#     if temp[1]=='Title':
#         continue
#     prompts.append(temp[1])
# f.close()
# print(prompts[930:945])

# print(len(prompts))

# %%
# new_list = []

# for i in prompts:
#   new_list.append(i)

# len(new_list)

# %%
# # Don't use this one (3/17) issues with generating for all of the prompts

# def generate_gpt3_response(user_text, print_output=False):
#     """
#     Query OpenAI GPT-3 for the specific key and get back a response
#     :type user_text: str the user's text to query for
#     :type print_output: boolean whether or not to print the raw output JSON
#     """
#     completions = ai.Completion.create(
#         engine='text-curie-001',  # Determines the quality, speed, and cost.
#         temperature=0.9,            # Level of creativity in the response
#         prompt=user_text,           # What the user typed in
#         max_tokens=500,             # Maximum tokens in the prompt AND response
#         n=1,                        # The number of completions to generate
#         stop=None,                  # An optional setting to control response generation
#     )

#     # Displaying the output can be helpful if things go wrong
#     if print_output:
#         print(completions)

#     # Return the first choice's text
#     return completions.choices[0].text


# f = open("/content/drive/MyDrive/NLP Group Project/gpt3_prompts.txt","w")
# gpt3_results = []
# for i in prompts:
#   text_generated = generate_gpt3_response(i)
#   gpt3_results.append(text_generated)
#   f.write(text_generated)

# print(gpt3_results)
# f.close()

# gpt3_df = pd.DataFrame(gpt3_results)
# gpt3_results.to_csv()

# f=open(".\data\gpt3_prompt_result.json","w")
# results = {}
# for i in prompts[0:899]:
#   text_generated = generate_gpt3_response(i)
#   results[i] = text_generated
#   # f.write(text_generated)

# import json

# temp = json.dumps(results)
# f.write(temp)
# f.close()
# print(results)
# print(len(results))

# print(len(temp))

# %%
prompts=[]
f = open("/content/drive/MyDrive/NLP Group Project/Texts/gpt2_generate.csv","r")
c=0
for i in f:
    temp = i.split(",")
    if temp[1]=='Title':
        continue
    prompts.append(temp[1])
f.close()
print(prompts)
print(len(prompts))
# Out:
# ['Latest Headlines on CNN Business', 'China wants to take a victory lap over its handling of the coronavirus outbreak', "Coronavirus disinformation creates challenges for China's government", "China coronavirus: Eating wild animals made illegal but ending the trade won't be easy", "China's economy could shrink for the first time in decades because of the coronavirus", "China and Japan's budding relationship in the time of coronavirus", "Coronavirus is fast becoming an 'economic pandemic'", '"A history of Wuhan', 'Global stocks pull back from the edge after historic sell-off', 'Chinese diplomat promotes conspiracy theory that US military brought virus to Wuhan', '"Putin and Xi are using the coronavirus crisis to extend their control. Across the world', 'How this South Korean company created coronavirus test kits in three weeks', "The 30 most troubling lines from Donald Trump's latest news conference on coronavirus", 'Coronavirus could hurt Boeing more than the 737 Max crisis', 'Hong K
# ...

# %%
def generate_instructgpt_response(user_text, print_output=False):
    """
    Query OpenAI GPT-3 for the specific key and get back a response
    :type user_text: str the user's text to query for
    :type print_output: boolean whether or not to print the raw output JSON
    """
    completions = ai.Completion.create(
        engine='text-davinci-003',  # Determines the quality, speed, and cost.
        temperature=0.9,            # Level of creativity in the response
        prompt=user_text,           # What the user typed in
        max_tokens=500,             # Maximum tokens in the prompt AND response
        n=1,                        # The number of completions to generate
        stop=None,                  # An optional setting to control response generation
    )

    # Displaying the output can be helpful if things go wrong
    return completions.choices[0].text


f=open("/content/drive/MyDrive/NLP Project/prompts.txt","w")
instruct_gpt_results = []
for i in prompts:
  text_generated = generate_instructgpt_response(i)
  instruct_gpt_results.append(text_generated)
  # f.write(text_generated)

print(instruct_gpt_results)
f.close()

# %%
# print(instruct_gpt_results)

# %%
def generate_gpt3_response(user_text, print_output=False):
    """
    Query OpenAI GPT-3 for the specific key and get back a response
    :type user_text: str the user's text to query for
    :type print_output: boolean whether or not to print the raw output JSON
    """
    completions = ai.Completion.create(
        engine='text-curie-001',  # Determines the quality, speed, and cost.
        temperature=0.9,            # Level of creativity in the response
        prompt=user_text,           # What the user typed in
        max_tokens=500,             # Maximum tokens in the prompt AND response
        n=1,                        # The number of completions to generate
        stop=None,                  # An optional setting to control response generation
    )

    # Displaying the output can be helpful if things go wrong
    return completions.choices[0].text

prompt_generation = []
c=0
for i in prompts:
  # prompt_no.append(c)
  text_generated = generate_gpt3_response(i)
  prompt_generation.append([c,i,text_generated])
  c+=1
  print(c, i)
  
import pandas as pd
result_df = pd.DataFrame(prompt_generation,columns=['No.','Titles','Generation'])
print(result_df)
# print(result_df.shape())
with open('gpt3_generate.csv', 'w') as csv_file:
    result_df.to_csv(path_or_buf=csv_file)
# Out:
# 1 Latest Headlines on CNN Business
# 2 China wants to take a victory lap over its handling of the coronavirus outbreak
# 3 Coronavirus disinformation creates challenges for China's government
# 4 China coronavirus: Eating wild animals made illegal but ending the trade won't be easy
# 5 China's economy could shrink for the first time in decades because of the coronavirus
# 6 China and Japan's budding relationship in the time of coronavirus
# 7 Coronavirus is fast becoming an 'economic pandemic'
# 8 "A history of Wuhan
# 9 Global stocks pull back from the edge after historic sell-off
# 10 Chinese diplomat promotes conspiracy theory that US military brought virus to Wuhan
# 11 "Putin and Xi are using the coronavirus crisis to extend their control. Across the world
# 12 How this South Korean company created coronavirus test kits in three weeks
# 13 The 30 most troubling lines from Donald Trump's latest news conference on coronavirus
# ...

# %%
# Reddit data in pickle file

df = joblib.load('/content/drive/MyDrive/NLP Group Project/Reddit_Data.pkl')

# len(df)

# %%
reddit_prompts = []

for item in df['Processed_Title']:
  reddit_prompts.append(item)

# print(len(reddit_prompts))

# %%
def generate_gpt3_response(user_text, print_output=False):
    """
    Query OpenAI GPT-3 for the specific key and get back a response
    :type user_text: str the user's text to query for
    :type print_output: boolean whether or not to print the raw output JSON
    """
    completions = ai.Completion.create(
        engine='text-curie-001',  # Determines the quality, speed, and cost.
        temperature=0.9,            # Level of creativity in the response
        prompt=user_text,           # What the user typed in
        max_tokens=500,             # Maximum tokens in the prompt AND response
        n=1,                        # The number of completions to generate
        stop=None,                  # An optional setting to control response generation
    )

    # Displaying the output can be helpful if things go wrong
    return completions.choices[0].text

prompt_generation = []
c=0
for i in reddit_prompts:
  # prompt_no.append(c)
  text_generated = generate_gpt3_response(i)
  prompt_generation.append([c,i,text_generated])
  c+=1
  
result_df = pd.DataFrame(prompt_generation,columns=['No.','Titles','Generation'])
print(result_df)
with open('gpt3_generate_reddit.csv', 'w') as csv_file:
    result_df.to_csv(path_or_buf=csv_file)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-80-4241163abcca> in <module>
#      21 for i in reddit_prompts:
#      22   # prompt_no.append(c)
# ---> 23   text_generated = generate_gpt3_response(i)
#      24   prompt_generation.append([c,i,text_generated])
#      25   c+=1
#
# <ipython-input-80-4241163abcca> in generate_gpt3_response(user_text, print_output)
#       5     :type print_output: boolean whether or not to print the raw output JSON
#       6     """
# ----> 7     completions = ai.Completion.create(
#       8         engine='text-curie-001',  # Determines the quality, speed, and cost.
#       9         temperature=0.9,            # Level of creativity in the response
#
# /usr/local/lib/python3.9/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ...
